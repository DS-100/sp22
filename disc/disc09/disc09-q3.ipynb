# %% [markdown]
# # Discussion 9
# ## Question 3: Feature Engineering

# %% [markdown]
# Your task in groups/breakout rooms is ultimately to share with the discussion section a visualization that demonstrates a feature that is useful in predicting the sale price of a house. To that end:
#
# 1. Introduce yourself to one another and share some features that you think would be useful in predicting the sale price of a house.
# 2. Decide on a distinct feature that each group member is in charge of exploring
# 3. Each member should try several different plot types and data transformations to clearly show the ability to (linearly) predict sale price well. Things to try:
#     - Transformations (log, sqrt(), squared)
#     - Removal of outliers
# 4. Once each member has their best visualization, share them with one another and decide upon one to paste to the padlet along with your names.
# 5. If you have extra time, construct a plot that illustrates how 2, 3, 4, or 5 features can be used to predict price. Your group can paste this second plot into padlet.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# The cell below loads a subset of the dataset from the Cook County Assessor's Office (CCAO) on housing sales in Cook Country, IL in HW7.

# %%
ccao = pd.read_csv("cook_county_small.csv")
ccao.head()
# Out:
#               PIN  Property Class  Neighborhood Code  Land Square Feet  \
# 0  24272020310000             203                210            8958.0
# 1  15152130170000             203                 31            5280.0
# 2   2232160110000             203                 60           11340.0
# 3  12162140220000             203                 20           10572.0
# 4  20074120280000             202                 91            3125.0
#
#    Town Code  Apartments  Wall Material  Roof Material  Basement  \
# 0         39         0.0            3.0            1.0       1.0
# 1         31         0.0            1.0            1.0       1.0
# 2         29         0.0            2.0            1.0       3.0
# 3         20         0.0            3.0            1.0       1.0
# 4         72         0.0            2.0            1.0       1.0
#
#    Basement Finish  ...  Lot Size Squared  Improvement Size Squared  \
# 0              1.0  ...        80245764.0                 1149184.0
# 1              3.0  ...        27878400.0                 1435204.0
# 2              3.0  ...       128595600.0                 1040400.0
# 3              1.0  ...       111767184.0                 1073296.0
# 4              1.0  ...         9765625.0                  804609.0
#
#    Pure Market Filter  Garage Indicator  Neigborhood Code (mapping)  \
# 0                   1               1.0                         210
# 1                   1               1.0                          31
# 2                   1               1.0                          60
# 3                   1               0.0                          20
# 4                   1               0.0                          91
#
#    Square root of lot size  Square root of age  \
# 0                94.646712            7.071068
# 1                72.663608            7.745967
# 2               106.489436            8.306624
# 3               102.820231            7.681146
# 4                55.901699            9.273618
#
#    Square root of improvement size  Town and Neighborhood  \
# 0                        32.741411                  39210
# 1                        34.612137                   3131
# 2                        31.937439                   2960
# 3                        32.186954                   2020
# 4                        29.949958                   7291
#
#                                          Description
# 0  This property, sold on 08/15/2014, is a one-st...
# 1  This property, sold on 11/21/2017, is a one-st...
# 2  This property, sold on 09/07/2018, is a one-st...
# 3  This property, sold on 01/24/2018, is a one-st...
# 4  This property, sold on 10/23/2014, is a one-st...
#
# [5 rows x 68 columns]

# %% [markdown]
# Use the cell below, adding any as necessary, to generate a few data visualizations that will help you select features to model `Sale Price` from `ccao`.
#
# Your group should upload **at least one** image to the padlet to get full credit for today's discussion.
